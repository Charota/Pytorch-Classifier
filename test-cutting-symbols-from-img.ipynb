# %%
import torch

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1050'

# %%
import cv2

# %%
from matplotlib import pyplot as plt

# %%
tempImg = cv2.imread('72a7931f-c4b7-4039-8d03-80771fbed2d7.jpg')

# %%
new_width = 400
new_height = 150
new_size = (new_width, new_height)
tempImg = cv2.resize(tempImg, new_size, interpolation= cv2.INTER_LINEAR)

# %%
plt.imshow(tempImg)
plt.title('my picture')
plt.show()

# %%
cutImg = tempImg[124:150, 131:136]
cutImg = cv2.resize(cutImg, (32,32), interpolation= cv2.INTER_LINEAR)

# %%
plt.imshow(cutImg)
plt.title('my picture')
plt.show()
